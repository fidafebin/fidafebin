# %% [markdown]
# <a href="https://colab.research.google.com/github/fidafebin/fidafebin/blob/main/panda's_note.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import seaborn as sns

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-48276b6f-320a-417c-b464-97f3a8dc5f7d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-48276b6f-320a-417c-b464-97f3a8dc5f7d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df=pd.read_csv('Salaries (1).csv')

# %%
df.head()
# Out:
#    rank discipline  phd  service   sex  salary
# 0  Prof          B   56       49  Male  186960
# 1  Prof          A   12        6  Male   93000
# 2  Prof          A   23       20  Male  110515
# 3  Prof          A   40       31  Male  131205
# 4  Prof          B   20       18  Male  104800

# %%
df.tail()
# Out:
#          rank discipline  phd  service     sex  salary
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646

# %%
df.sample(5)
# Out:
#          rank discipline  phd  service     sex  salary
# 75       Prof          B   17       17  Female  124312
# 48       Prof          B   17       17  Female  111512
# 55   AsstProf          A    2        0  Female   72500
# 29       Prof          B   21       20    Male  123683
# 47  AssocProf          B   11       11  Female  103613

# %%
df.tail(10)
# Out:
#          rank discipline  phd  service     sex  salary
# 68   AsstProf          A    4        2  Female   77500
# 69       Prof          A   28        7  Female  116450
# 70   AsstProf          A    8        3  Female   78500
# 71  AssocProf          B   12        9  Female   71065
# 72       Prof          B   24       15  Female  161101
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646

# %%
df.sample(10)
# Out:
#         rank discipline  phd  service     sex  salary
# 21      Prof          A   33       30    Male  103106
# 45      Prof          B   25       25  Female  140096
# 69      Prof          A   28        7  Female  116450
# 27      Prof          A   45       43    Male  155865
# 39      Prof          B   18       18  Female  129000
# 67      Prof          A   17       11  Female   90450
# 16  AsstProf          B    8        3    Male   75044
# 73      Prof          B   18       10  Female  105450
# 18      Prof          A   19        7    Male  107300
# 31      Prof          B   22       21    Male  155750

# %%
df.head(20)
# Out:
#          rank discipline  phd  service   sex  salary
# 0        Prof          B   56       49  Male  186960
# 1        Prof          A   12        6  Male   93000
# 2        Prof          A   23       20  Male  110515
# 3        Prof          A   40       31  Male  131205
# 4        Prof          B   20       18  Male  104800
# 5        Prof          A   20       20  Male  122400
# 6   AssocProf          A   20       17  Male   81285
# 7        Prof          A   18       18  Male  126300
# 8        Prof          A   29       19  Male   94350
# 9        Prof          A   51       51  Male   57800
# 10       Prof          B   39       33  Male  128250
# 11       Prof          B   23       23  Male  134778
# 12   AsstProf          B    1        0  Male   88000
# 13       Prof          B   35       33  Male  162200
# 14       Prof          B   25       19  Male  153750
# 15       Prof          B   17        3  Male  150480
# 16   AsstProf          B    8        3  Male   75044
# ...

# %%
df.tail(20)
# Out:
#          rank discipline  phd  service     sex  salary
# 58       Prof          B   36       26  Female  144651
# 59  AssocProf          B   12       10  Female  103994
# 60   AsstProf          B    3        3  Female   92000
# 61  AssocProf          B   13       10  Female  103750
# 62  AssocProf          B   14        7  Female  109650
# 63       Prof          A   29       27  Female   91000
# 64  AssocProf          A   26       24  Female   73300
# 65       Prof          A   36       19  Female  117555
# 66   AsstProf          A    7        6  Female   63100
# 67       Prof          A   17       11  Female   90450
# 68   AsstProf          A    4        2  Female   77500
# 69       Prof          A   28        7  Female  116450
# 70   AsstProf          A    8        3  Female   78500
# 71  AssocProf          B   12        9  Female   71065
# 72       Prof          B   24       15  Female  161101
# 73       Prof          B   18       10  Female  105450
# ...

# %%
df.sample(20)
# Out:
#          rank discipline  phd  service     sex  salary
# 20   AsstProf          B    4        4    Male   92000
# 19       Prof          A   29       27    Male  150500
# 65       Prof          A   36       19  Female  117555
# 61  AssocProf          B   13       10  Female  103750
# 50   AsstProf          B   10        5  Female   97032
# 31       Prof          B   22       21    Male  155750
# 16   AsstProf          B    8        3    Male   75044
# 72       Prof          B   24       15  Female  161101
# 56  AssocProf          A   10        8  Female   77500
# 70   AsstProf          A    8        3  Female   78500
# 32       Prof          A   27       19    Male  103275
# 45       Prof          B   25       25  Female  140096
# 54  AssocProf          A   25       22  Female   62884
# 52       Prof          A   12        0  Female  105000
# 51       Prof          B   20       14  Female  127512
# 35       Prof          B   28       23    Male  126933
# ...

# %%
df.head(50)
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# 5        Prof          A   20       20    Male  122400
# 6   AssocProf          A   20       17    Male   81285
# 7        Prof          A   18       18    Male  126300
# 8        Prof          A   29       19    Male   94350
# 9        Prof          A   51       51    Male   57800
# 10       Prof          B   39       33    Male  128250
# 11       Prof          B   23       23    Male  134778
# 12   AsstProf          B    1        0    Male   88000
# 13       Prof          B   35       33    Male  162200
# 14       Prof          B   25       19    Male  153750
# 15       Prof          B   17        3    Male  150480
# ...

# %%
df.tail(50)
# Out:
#          rank discipline  phd  service     sex  salary
# 28   AsstProf          B    7        2    Male   91300
# 29       Prof          B   21       20    Male  123683
# 30  AssocProf          B    9        7    Male  107008
# 31       Prof          B   22       21    Male  155750
# 32       Prof          A   27       19    Male  103275
# 33       Prof          B   18       18    Male  120000
# 34  AssocProf          B   12        8    Male  119800
# 35       Prof          B   28       23    Male  126933
# 36       Prof          B   45       45    Male  146856
# 37       Prof          A   20        8    Male  102000
# 38   AsstProf          B    4        3    Male   91000
# 39       Prof          B   18       18  Female  129000
# 40       Prof          A   39       36  Female  137000
# 41  AssocProf          A   13        8  Female   74830
# 42   AsstProf          B    4        2  Female   80225
# 43   AsstProf          B    5        0  Female   77000
# ...

# %%
df.sample(50)
# Out:
#          rank discipline  phd  service     sex  salary
# 21       Prof          A   33       30    Male  103106
# 54  AssocProf          A   25       22  Female   62884
# 5        Prof          A   20       20    Male  122400
# 52       Prof          A   12        0  Female  105000
# 7        Prof          A   18       18    Male  126300
# 74  AssocProf          B   19        6  Female  104542
# 64  AssocProf          A   26       24  Female   73300
# 37       Prof          A   20        8    Male  102000
# 11       Prof          B   23       23    Male  134778
# 18       Prof          A   19        7    Male  107300
# 53   AsstProf          A    5        3  Female   73500
# 22   AsstProf          A    4        2    Male   73000
# 28   AsstProf          B    7        2    Male   91300
# 42   AsstProf          B    4        2  Female   80225
# 62  AssocProf          B   14        7  Female  109650
# 29       Prof          B   21       20    Male  123683
# ...

# %%
df.columns
# Out:
# Index(['rank', 'discipline', 'phd', 'service', 'sex', 'salary'], dtype='object')

# %%
df.dtypes
# Out:
# rank          object
# discipline    object
# phd            int64
# service        int64
# sex           object
# salary         int64
# dtype: object

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=78, step=1),
#  Index(['rank', 'discipline', 'phd', 'service', 'sex', 'salary'], dtype='object')]

# %%
df.ndim
# Out:
# 2

# %%
df.size
# Out:
# 468

# %%
df.shape
# Out:
# (78, 6)

# %%
df.values
# Out:
# array([['Prof', 'B', 56, 49, 'Male', 186960],
#        ['Prof', 'A', 12, 6, 'Male', 93000],
#        ['Prof', 'A', 23, 20, 'Male', 110515],
#        ['Prof', 'A', 40, 31, 'Male', 131205],
#        ['Prof', 'B', 20, 18, 'Male', 104800],
#        ['Prof', 'A', 20, 20, 'Male', 122400],
#        ['AssocProf', 'A', 20, 17, 'Male', 81285],
#        ['Prof', 'A', 18, 18, 'Male', 126300],
#        ['Prof', 'A', 29, 19, 'Male', 94350],
#        ['Prof', 'A', 51, 51, 'Male', 57800],
#        ['Prof', 'B', 39, 33, 'Male', 128250],
#        ['Prof', 'B', 23, 23, 'Male', 134778],
#        ['AsstProf', 'B', 1, 0, 'Male', 88000],
#        ['Prof', 'B', 35, 33, 'Male', 162200],
#        ['Prof', 'B', 25, 19, 'Male', 153750],
#        ['Prof', 'B', 17, 3, 'Male', 150480],
#        ['AsstProf', 'B', 8, 3, 'Male', 75044],
#        ['AsstProf', 'B', 4, 0, 'Male', 92000],
#        ['Prof', 'A', 19, 7, 'Male', 107300],
#        ['Prof', 'A', 29, 27, 'Male', 150500],
# ...

# %%
df.shape
# Out:
# (78, 6)

# %%
df.shape[0]
# Out:
# 78

# %%
df.shape[1]
# Out:
# 6

# %%
df.describe()
# Out:
#              phd    service         salary
# count  78.000000  78.000000      78.000000
# mean   19.705128  15.051282  108023.782051
# std    12.498425  12.139768   28293.661022
# min     1.000000   0.000000   57800.000000
# 25%    10.250000   5.250000   88612.500000
# 50%    18.500000  14.500000  104671.000000
# 75%    27.750000  20.750000  126774.750000
# max    56.000000  51.000000  186960.000000

# %%
df.mean()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# phd            19.705128
# service        15.051282
# salary     108023.782051
# dtype: float64

# %%
df.median()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# phd            18.5
# service        14.5
# salary     104671.0
# dtype: float64

# %%
df.std()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# phd           12.498425
# service       12.139768
# salary     28293.661022
# dtype: float64

# %%
df['salary'].max()
# Out:
# 186960

# %%
df['salary'].mean()
# Out:
# 108023.78205128205

# %%
df['phd'].std()
# Out:
# 12.498424809175864

# %%
df['phd'].mean()
# Out:
# 19.705128205128204

# %%
df['service'].mean()
# Out:
# 15.051282051282051

# %%
df['service'].median()
# Out:
# 14.5

# %%
df['phd'].median()
# Out:
# 18.5

# %%
df.isnull().sum()
# Out:
# rank          0
# discipline    0
# phd           0
# service       0
# sex           0
# salary        0
# dtype: int64

# %%
df.isnull().any()
# Out:
# rank          False
# discipline    False
# phd           False
# service       False
# sex           False
# salary        False
# dtype: bool

# %%
df.head(50).mean()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# phd            21.52
# service        17.60
# salary     113789.14
# dtype: float64

# %%
df['phd']
# Out:
# 0     56
# 1     12
# 2     23
# 3     40
# 4     20
#       ..
# 73    18
# 74    19
# 75    17
# 76    28
# 77    23
# Name: phd, Length: 78, dtype: int64

# %%
df['phd'].describe()
# Out:
# count    78.000000
# mean     19.705128
# std      12.498425
# min       1.000000
# 25%      10.250000
# 50%      18.500000
# 75%      27.750000
# max      56.000000
# Name: phd, dtype: float64

# %%
df['phd'].count()
# Out:
# 78

# %%
df['phd'].size
# Out:
# 78

# %%
df_rank=df.groupby(['rank'])

# %%
df_rank

# %%
df_rank.mean()
# Out:
#                  phd    service         salary
# rank
# AssocProf  15.076923  11.307692   91786.230769
# AsstProf    5.052632   2.210526   81362.789474
# Prof       27.065217  21.413043  123624.804348

# %%
df.groupby(['discipline']).mean()
# Out:
#                   phd    service         salary
# discipline
# A           21.527778  15.722222   98331.111111
# B           18.142857  14.476190  116331.785714

# %%
df.groupby('discipline')[['service']].mean()
# Out:
#               service
# discipline
# A           15.722222
# B           14.476190

# %%
df.groupby('sex',sort=False)[['salary']].mean()
# Out:
#                salary
# sex
# Male    115045.153846
# Female  101002.410256

# %%
df[df['salary']<130000]
# Out:
#          rank discipline  phd  service     sex  salary
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 4        Prof          B   20       18    Male  104800
# 5        Prof          A   20       20    Male  122400
# 6   AssocProf          A   20       17    Male   81285
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [62 rows x 6 columns]

# %%
df[(df['salary']<=150000)&(df['salary']>=100000)&(df['rank']=='Prof')&(df['discipline']=='A')&(df['sex']=='Female')]
# Out:
#     rank discipline  phd  service     sex  salary
# 40  Prof          A   39       36  Female  137000
# 52  Prof          A   12        0  Female  105000
# 65  Prof          A   36       19  Female  117555
# 69  Prof          A   28        7  Female  116450
# 76  Prof          A   28       14  Female  109954
# 77  Prof          A   23       15  Female  109646

# %%
df['rank'].value_counts()
# Out:
# Prof         46
# AsstProf     19
# AssocProf    13
# Name: rank, dtype: int64

# %%
df[(df['salary']<=120000)&(df['salary']>=100000)&(df['rank']=='AssocProf')&(df['sex']=='Male')]
# Out:
#          rank discipline  phd  service   sex  salary
# 30  AssocProf          B    9        7  Male  107008
# 34  AssocProf          B   12        8  Male  119800

# %%
df['discipline'].value_counts()
# Out:
# B    42
# A    36
# Name: discipline, dtype: int64

# %%
pd.set_option('display.max_rows',None)

# %%
df
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# 5        Prof          A   20       20    Male  122400
# 6   AssocProf          A   20       17    Male   81285
# 7        Prof          A   18       18    Male  126300
# 8        Prof          A   29       19    Male   94350
# 9        Prof          A   51       51    Male   57800
# 10       Prof          B   39       33    Male  128250
# 11       Prof          B   23       23    Male  134778
# 12   AsstProf          B    1        0    Male   88000
# 13       Prof          B   35       33    Male  162200
# 14       Prof          B   25       19    Male  153750
# 15       Prof          B   17        3    Male  150480
# ...

# %%
df[["salary","rank"]]
# Out:
#     salary       rank
# 0   186960       Prof
# 1    93000       Prof
# 2   110515       Prof
# 3   131205       Prof
# 4   104800       Prof
# 5   122400       Prof
# 6    81285  AssocProf
# 7   126300       Prof
# 8    94350       Prof
# 9    57800       Prof
# 10  128250       Prof
# 11  134778       Prof
# 12   88000   AsstProf
# 13  162200       Prof
# 14  153750       Prof
# 15  150480       Prof
# 16   75044   AsstProf
# 17   92000   AsstProf
# 18  107300       Prof
# 19  150500       Prof
# 20   92000   AsstProf
# 21  103106       Prof
# 22   73000   AsstProf
# 23   85000   AsstProf
# 24   91100       Prof
# 25   99418       Prof
# 26  148750       Prof
# 27  155865       Prof
# 28   91300   AsstProf
# 29  123683       Prof
# 30  107008  AssocProf
# 31  155750       Prof
# 32  103275       Prof
# 33  120000       Prof
# 34  119800  AssocProf
# 35  126933       Prof
# 36  146856       Prof
# 37  102000       Prof
# 38   91000   AsstProf
# 39  129000       Prof
# ...

# %%
df.iloc[0:4]
# Out:
#    rank discipline  phd  service   sex  salary
# 0  Prof          B   56       49  Male  186960
# 1  Prof          A   12        6  Male   93000
# 2  Prof          A   23       20  Male  110515
# 3  Prof          A   40       31  Male  131205

# %%
df.iloc[2:5]
# Out:
#    rank discipline  phd  service   sex  salary
# 2  Prof          A   23       20  Male  110515
# 3  Prof          A   40       31  Male  131205
# 4  Prof          B   20       18  Male  104800

# %%
df.iloc[1:5,3:6]
# Out:
#    service   sex  salary
# 1        6  Male   93000
# 2       20  Male  110515
# 3       31  Male  131205
# 4       18  Male  104800

# %%
df.iloc[0:4,-3:]
# Out:
#    service   sex  salary
# 0       49  Male  186960
# 1        6  Male   93000
# 2       20  Male  110515
# 3       31  Male  131205

# %%
df.iloc[0]
# Out:
# rank            Prof
# discipline         B
# phd               56
# service           49
# sex             Male
# salary        186960
# Name: 0, dtype: object

# %%
df.iloc[:,0:3]
# Out:
#          rank discipline  phd
# 0        Prof          B   56
# 1        Prof          A   12
# 2        Prof          A   23
# 3        Prof          A   40
# 4        Prof          B   20
# 5        Prof          A   20
# 6   AssocProf          A   20
# 7        Prof          A   18
# 8        Prof          A   29
# 9        Prof          A   51
# 10       Prof          B   39
# 11       Prof          B   23
# 12   AsstProf          B    1
# 13       Prof          B   35
# 14       Prof          B   25
# 15       Prof          B   17
# 16   AsstProf          B    8
# 17   AsstProf          B    4
# 18       Prof          A   19
# 19       Prof          A   29
# 20   AsstProf          B    4
# 21       Prof          A   33
# 22   AsstProf          A    4
# 23   AsstProf          A    2
# 24       Prof          A   30
# 25       Prof          B   35
# 26       Prof          A   38
# 27       Prof          A   45
# 28   AsstProf          B    7
# 29       Prof          B   21
# ...

# %%
df[['phd','salary']].agg(['min','max','mean'])
# Out:
#             phd         salary
# min    1.000000   57800.000000
# max   56.000000  186960.000000
# mean  19.705128  108023.782051

# %%
print('The average salary of prof is Rs.',df[df['rank']=='Prof']['salary'].mean())
# Out:
# The average salary of prof is Rs. 123624.80434782608
